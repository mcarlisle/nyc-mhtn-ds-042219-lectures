# %%
from scipy.stats import binom
p = 0.55
for n in range(50,101):
    majority_prob = sum([binom.pmf(k,n,p) for k in range(n//2 + 1,n + 1)])
    print(f"n = {n}: P(majority agree) = {majority_prob}")
    if majority_prob > 0.8:
        print(f"    {n} amateurs probabilistically score better than the expert!")
# Out:
# n = 50: P(majority agree) = 0.7160393302496592
# n = 51: P(majority agree) = 0.7640708453331891
# n = 52: P(majority agree) = 0.7216737964421648
# n = 53: P(majority agree) = 0.7683105502222948
# n = 54: P(majority agree) = 0.7271147510498471
# n = 55: P(majority agree) = 0.7724301301395475
# n = 56: P(majority agree) = 0.7323745718370432
# n = 57: P(majority agree) = 0.7764356859697702
# n = 58: P(majority agree) = 0.7374643901937552
# n = 59: P(majority agree) = 0.7803328155473754
# n = 60: P(majority agree) = 0.7423942591094419
# n = 61: P(majority agree) = 0.7841266711911924
# n = 62: P(majority agree) = 0.7471732933961909
# n = 63: P(majority agree) = 0.7878220089706656
# n = 64: P(majority agree) = 0.7518097875164134
# n = 65: P(majority agree) = 0.791423231116089
# n = 66: P(majority agree) = 0.7563113151981984
# n = 67: P(majority agree) = 0.7949344227079123
# n = 68: P(majority agree) = 0.7606848141368152
# n = 69: P(majority agree) = 0.7983593835650241
# n = 70: P(majority agree) = 0.7649366584008174
# n = 71: P(majority agree) = 0.801701656081417
#     71 amateurs probabilistically score better than the expert!
# n = 72: P(majority agree) = 0.7690727206399194
# n = 73: P(majority agree) = 0.8049645496255867
#     73 amateurs probabilistically score better than the expert!
# n = 74: P(majority agree) = 0.773098425782855
# n = 75: P(majority agree) = 0.8081511620098392
#     75 amateurs probabilistically score better than the expert!
# n = 76: P(majority agree) = 0.7770187975977499
# n = 77: P(majority agree) = 0.8112643984510564
#     77 amateurs probabilistically score better than the expert!
# n = 78: P(majority agree) = 0.7808384992313627
# n = 79: P(majority agree) = 0.8143069883729539
#     79 amateurs probabilistically score better than the expert!
# n = 80: P(majority agree) = 0.7845618686484186
# n = 81: P(majority agree) = 0.8172815003455022
#     81 amateurs probabilistically score better than the expert!
# n = 82: P(majority agree) = 0.7881929497270045
# n = 83: P(majority agree) = 0.820190355407328
#     83 amateurs probabilistically score better than the expert!
# n = 84: P(majority agree) = 0.7917355196415562
# n = 85: P(majority agree) = 0.8230358389838778
#     85 amateurs probabilistically score better than the expert!
# n = 86: P(majority agree) = 0.7951931130572707
# n = 87: P(majority agree) = 0.8258201115765621
#     87 amateurs probabilistically score better than the expert!
# n = 88: P(majority agree) = 0.7985690435758798
# n = 89: P(majority agree) = 0.8285452183765626
#     89 amateurs probabilistically score better than the expert!
# n = 90: P(majority agree) = 0.8018664228039545
#     90 amateurs probabilistically score better than the expert!
# n = 91: P(majority agree) = 0.831213097933907
#     91 amateurs probabilistically score better than the expert!
# n = 92: P(majority agree) = 0.8050881773563097
#     92 amateurs probabilistically score better than the expert!
# n = 93: P(majority agree) = 0.833825589991649
#     93 amateurs probabilistically score better than the expert!
# n = 94: P(majority agree) = 0.8082370640599217
#     94 amateurs probabilistically score better than the expert!
# n = 95: P(majority agree) = 0.836384442584771
#     95 amateurs probabilistically score better than the expert!
# n = 96: P(majority agree) = 0.8113156835861052
#     96 amateurs probabilistically score better than the expert!
# n = 97: P(majority agree) = 0.8388913184846913
#     97 amateurs probabilistically score better than the expert!
# n = 98: P(majority agree) = 0.8143264927025524
#     98 amateurs probabilistically score better than the expert!
# n = 99: P(majority agree) = 0.8413478010628871
#     99 amateurs probabilistically score better than the expert!
# n = 100: P(majority agree) = 0.8172718153138253
#     100 amateurs probabilistically score better than the expert!

# %%
p = 0.55
for n in range(50,101):
    majority_prob = 1 - binom.cdf(n // 2, n, p)
    print(f"n = {n}: P(majority agree) = {majority_prob}")
    if majority_prob > 0.8:
        print(f"    {n} amateurs probabilistically score better than the expert!")
# Out:
# n = 50: P(majority agree) = 0.7160393302496646
# n = 51: P(majority agree) = 0.7640708453331759
# n = 52: P(majority agree) = 0.7216737964421535
# n = 53: P(majority agree) = 0.7683105502222782
# n = 54: P(majority agree) = 0.7271147510498348
# n = 55: P(majority agree) = 0.7724301301395227
# n = 56: P(majority agree) = 0.7323745718370306
# n = 57: P(majority agree) = 0.7764356859697719
# n = 58: P(majority agree) = 0.7374643901937441
# n = 59: P(majority agree) = 0.7803328155473745
# n = 60: P(majority agree) = 0.7423942591094113
# n = 61: P(majority agree) = 0.7841266711911709
# n = 62: P(majority agree) = 0.7471732933961936
# n = 63: P(majority agree) = 0.7878220089706686
# n = 64: P(majority agree) = 0.751809787516407
# n = 65: P(majority agree) = 0.7914232311160947
# n = 66: P(majority agree) = 0.75631131519819
# n = 67: P(majority agree) = 0.7949344227078856
# n = 68: P(majority agree) = 0.7606848141367876
# n = 69: P(majority agree) = 0.7983593835649955
# n = 70: P(majority agree) = 0.7649366584008286
# n = 71: P(majority agree) = 0.8017016560814119
#     71 amateurs probabilistically score better than the expert!
# n = 72: P(majority agree) = 0.769072720639894
# n = 73: P(majority agree) = 0.8049645496255635
#     73 amateurs probabilistically score better than the expert!
# n = 74: P(majority agree) = 0.7730984257828808
# n = 75: P(majority agree) = 0.8081511620098315
#     75 amateurs probabilistically score better than the expert!
# n = 76: P(majority agree) = 0.7770187975977378
# n = 77: P(majority agree) = 0.8112643984510411
#     77 amateurs probabilistically score better than the expert!
# n = 78: P(majority agree) = 0.7808384992313753
# n = 79: P(majority agree) = 0.814306988373008
#     79 amateurs probabilistically score better than the expert!
# n = 80: P(majority agree) = 0.7845618686483817
# n = 81: P(majority agree) = 0.8172815003454708
#     81 amateurs probabilistically score better than the expert!
# n = 82: P(majority agree) = 0.7881929497269613
# n = 83: P(majority agree) = 0.8201903554073214
#     83 amateurs probabilistically score better than the expert!
# n = 84: P(majority agree) = 0.7917355196415725
# n = 85: P(majority agree) = 0.8230358389838965
#     85 amateurs probabilistically score better than the expert!
# n = 86: P(majority agree) = 0.7951931130572943
# n = 87: P(majority agree) = 0.8258201115765563
#     87 amateurs probabilistically score better than the expert!
# n = 88: P(majority agree) = 0.7985690435758949
# n = 89: P(majority agree) = 0.8285452183766228
#     89 amateurs probabilistically score better than the expert!
# n = 90: P(majority agree) = 0.801866422803975
#     90 amateurs probabilistically score better than the expert!
# n = 91: P(majority agree) = 0.831213097933887
#     91 amateurs probabilistically score better than the expert!
# n = 92: P(majority agree) = 0.8050881773562807
#     92 amateurs probabilistically score better than the expert!
# n = 93: P(majority agree) = 0.833825589991648
#     93 amateurs probabilistically score better than the expert!
# n = 94: P(majority agree) = 0.808237064059943
#     94 amateurs probabilistically score better than the expert!
# n = 95: P(majority agree) = 0.8363844425848186
#     95 amateurs probabilistically score better than the expert!
# n = 96: P(majority agree) = 0.8113156835861013
#     96 amateurs probabilistically score better than the expert!
# n = 97: P(majority agree) = 0.8388913184846905
#     97 amateurs probabilistically score better than the expert!
# n = 98: P(majority agree) = 0.81432649270258
#     98 amateurs probabilistically score better than the expert!
# n = 99: P(majority agree) = 0.8413478010629016
#     99 amateurs probabilistically score better than the expert!
# n = 100: P(majority agree) = 0.8172718153138554
#     100 amateurs probabilistically score better than the expert!

# %%
import random
from numpy import mean
import matplotlib.pyplot as plt

N = 10000
N_samples = list(range(N))
bootstrap_uniques = []

for m in range(10000):
    N_bootstrap = [random.choice(N_samples) for i in range(N)]
    set_N_bootstrap = set(N_bootstrap)
    bootstrap_uniques.append(len(set_N_bootstrap))
    
ave_bootstrap_size = mean(bootstrap_uniques)
print(ave_bootstrap_size)
plt.hist(bootstrap_uniques)
plt.show();
# Out:
# 6321.0921

# %%
from math import exp, log

print(f"error = {(1 - exp(-1)) - (6321.0921/10000)}")
# Out:
# error = 1.1348828557689039e-05

# %%
def expected_coupon_collector_time(n):
    return round(1 + n * log(n), 3)

def expected_coupon_collector_time_sum(n):
    return round(1 + n * sum([1/i for i in range(1,n+1)]), 3)

# %%
for i in range(1,201):
    #print(f"{i}: {expected_coupon_collector_time(i * (1 - exp(-i)))}")
    print(f"{i}: {expected_coupon_collector_time(i)} vs {expected_coupon_collector_time_sum(i)}")
# Out:
# 1: 1.0 vs 2.0
# 2: 2.386 vs 4.0
# 3: 4.296 vs 6.5
# 4: 6.545 vs 9.333
# 5: 9.047 vs 12.417
# 6: 11.751 vs 15.7
# 7: 14.621 vs 19.15
# 8: 17.636 vs 22.743
# 9: 20.775 vs 26.461
# 10: 24.026 vs 30.29
# 11: 27.377 vs 34.219
# 12: 30.819 vs 38.239
# 13: 34.344 vs 42.342
# 14: 37.947 vs 46.522
# 15: 41.621 vs 50.773
# 16: 45.361 vs 55.092
# 17: 49.165 vs 59.472
# 18: 53.027 vs 63.912
# 19: 56.944 vs 68.407
# 20: 60.915 vs 72.955
